# %%
import os 
import pandas as pd
import seaborn as sns

# %%
folder_path = "/home/onyxia/work/Python_Project_2A/data/RTE"
files = [f for f in os.listdir(folder_path) if f.endswith(".xls")]

dfs = []
for file in files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path, sep='\t', encoding='latin-1')
    dfs.append(df)
    print(file_path)

df_ele = pd.concat(dfs, ignore_index=True)
# combined_df.to_csv("data_ele_2020-2024.csv", index=False)
# print(f"shape:{df_ele.shape}")
# Out:
# /tmp/ipykernel_6273/4214978603.py:7: DtypeWarning: Columns (12,13,14,15,18,20,21,22,24,30,32,33,34,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, sep='\t', encoding='latin-1')
# /home/onyxia/work/Python_Project_2A/data/RTE/eCO2mix_RTE_Ile-de-France_Annuel-Definitif_2021.xls
# /home/onyxia/work/Python_Project_2A/data/RTE/eCO2mix_RTE_Ile-de-France_Annuel-Definitif_2020.xls
# /home/onyxia/work/Python_Project_2A/data/RTE/eCO2mix_RTE_Ile-de-France_Annuel-Definitif_2023.xls
# /home/onyxia/work/Python_Project_2A/data/RTE/eCO2mix_RTE_Ile-de-France_Annuel-Definitif_2024.xls
# /home/onyxia/work/Python_Project_2A/data/RTE/eCO2mix_RTE_Ile-de-France_Annuel-Definitif_2022.xls

# %%
df_ele.tail()
# Out:
#                                                 Périmètre  \
# 175392                                      Ile-de-France
# 175393                                      Ile-de-France
# 175394                                      Ile-de-France
# 175395                                      Ile-de-France
# 175396  RTE ne pourra être tenu responsable de l'usage...
#
#                      Nature        Date Heures  Consommation  Thermique  \
# 175392  Données définitives  2022-12-31  23:00        7227.0      255.0
# 175393  Données définitives  2022-12-31  23:15           NaN        NaN
# 175394  Données définitives  2022-12-31  23:30        7128.0      257.0
# 175395  Données définitives  2022-12-31  23:45           NaN        NaN
# 175396                  NaN         NaN    NaN           NaN        NaN
#
#        Nucléaire  Eolien  Solaire  Hydraulique  ... TCH Eolien (%)  \
# 175392       0.0   133.0      0.0          8.0  ...          91.72
# 175393       NaN     NaN      NaN          NaN  ...            NaN
# 175394       0.0   131.0      0.0          8.0  ...          90.34
# 175395       NaN     NaN      NaN          NaN  ...            NaN
# 175396       NaN     NaN      NaN          NaN  ...            NaN
#
#         TCO Solaire (%) TCH Solaire (%) TCO Hydraulique (%)  \
# 175392              0.0             0.0                0.11
# 175393              NaN             NaN                 NaN
# 175394              0.0             0.0                0.11
# 175395              NaN             NaN                 NaN
# 175396              NaN             NaN                 NaN
#
#        TCH Hydraulique (%) TCO Bioénergies (%)  TCH Bioénergies (%)  \
# 175392               42.11                1.67                37.93
# 175393                 NaN                 NaN                  NaN
# 175394               42.11                1.74                38.87
# 175395                 NaN                 NaN                  NaN
# 175396                 NaN                 NaN                  NaN
#
#        Unnamed: 67 Unnamed: 65 Unnamed: 29
# 175392         NaN         NaN         NaN
# 175393         NaN         NaN         NaN
# 175394         NaN         NaN         NaN
# 175395         NaN         NaN         NaN
# 175396         NaN         NaN         NaN
#
# [5 rows x 70 columns]

# %%
df_ele.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175397 entries, 0 to 175396
# Data columns (total 70 columns):
#  #   Column                                                        Non-Null Count   Dtype
# ---  ------                                                        --------------   -----
#  0   Périmètre                                                     175397 non-null  object
#  1   Nature                                                        175392 non-null  object
#  2   Date                                                          175392 non-null  object
#  3   Heures                                                        175392 non-null  object
#  4   Consommation                                                  87696 non-null   float64
#  5   Thermique                                                     87696 non-null   float64
#  6   Nucléaire                                                     87696 non-null   object
#  7   Eolien                                                        87696 non-null   float64
#  8   Solaire                                                       87696 non-null   float64
#  9   Hydraulique                                                   87696 non-null   float64
#  10  Pompage                                                       87696 non-null   object
#  11  Bioénergies                                                   87696 non-null   float64
#  12  Stockage batterie                                             87696 non-null   object
#  13  Déstockage batterie                                           87696 non-null   object
#  14  Eolien terrestre                                              70128 non-null   object
#  15  Eolien offshore                                               70128 non-null   object
#  16  Ech. physiques                                                87696 non-null   float64
#  17  Flux physiques d'Auvergne-Rhône-Alpes vers Ile-de-France      140256 non-null  object
#  18  Flux physiques de Bourgogne-Franche-Comté vers Ile-de-France  87696 non-null   object
#  19  Flux physiques de Bretagne vers Ile-de-France                 122688 non-null  object
#  20  Flux physiques de Centre-Val de Loire vers Ile-de-France      70128 non-null   object
#  21  Flux physiques de Grand-Est vers Ile-de-France                70128 non-null   object
#  22  Flux physiques de Hauts-de-France vers Ile-de-France          70128 non-null   object
#  23  Flux physiques d'Ile-de-France vers Ile-de-France             122688 non-null  object
#  24  Flux physiques de Normandie vers Ile-de-France                70128 non-null   object
#  25  Flux physiques de Nouvelle-Aquitaine vers Ile-de-France       122688 non-null  object
#  26  Flux physiques d'Occitanie vers Ile-de-France                 122688 non-null  object
#  27  Flux physiques de Pays-de-la-Loire vers Ile-de-France         122688 non-null  object
#  28  Flux physiques de PACA vers Ile-de-France                     122688 non-null  object
#  29  Flux physiques de Ile-de-France vers Auvergne-Rhône-Alpes     122688 non-null  object
#  30  Flux physiques de Ile-de-France vers Bourgogne-Franche-Comté  70128 non-null   object
#  31  Flux physiques de Ile-de-France vers Bretagne                 122688 non-null  object
#  32  Flux physiques de Ile-de-France vers Centre-Val de Loire      70128 non-null   object
#  33  Flux physiques de Ile-de-France vers Grand-Est                70128 non-null   object
#  34  Flux physiques de Ile-de-France vers Hauts-de-France          70128 non-null   object
#  35  Flux physiques de Ile-de-France vers Ile-de-France            122688 non-null  object
#  36  Flux physiques de Ile-de-France vers Normandie                70128 non-null   object
#  37  Flux physiques de Ile-de-France vers Nouvelle-Aquitaine       122688 non-null  object
#  38  Flux physiques de Ile-de-France vers Occitanie                122688 non-null  object
#  39  Flux physiques de Ile-de-France vers Pays-de-la-Loire         122688 non-null  object
#  40  Flux physiques de Ile-de-France vers PACA                     122688 non-null  object
#  41  Flux physiques Allemagne vers Ile-de-France                   122688 non-null  object
#  42  Flux physiques Belgique vers Ile-de-France                    122688 non-null  object
#  43  Flux physiques Espagne vers Ile-de-France                     122688 non-null  object
#  44  Flux physiques Italie vers Ile-de-France                      122688 non-null  object
#  45  Flux physiques Luxembourg vers Ile-de-France                  122688 non-null  object
#  46  Flux physiques Royaume-Uni vers Ile-de-France                 122688 non-null  object
#  47  Flux physiques Suisse vers Ile-de-France                      122688 non-null  object
#  48  Flux physiques de Ile-de-France vers Allemagne                122688 non-null  object
#  49  Flux physiques de Ile-de-France vers Belgique                 122688 non-null  object
#  50  Flux physiques de Ile-de-France vers Espagne                  122688 non-null  object
#  51  Flux physiques de Ile-de-France vers Italie                   122688 non-null  object
#  52  Flux physiques de Ile-de-France vers Luxembourg               122688 non-null  object
#  53  Flux physiques de Ile-de-France vers Royaume-Uni              122688 non-null  object
#  54  Flux physiques de Ile-de-France vers Suisse                   122688 non-null  object
#  55  TCO Thermique (%)                                             87696 non-null   float64
#  56  TCH Thermique (%)                                             87696 non-null   float64
#  57  TCO Nucléaire (%)                                             87696 non-null   object
#  58  TCH Nucléaire (%)                                             87696 non-null   object
#  59  TCO Eolien (%)                                                87696 non-null   float64
#  60  TCH Eolien (%)                                                87696 non-null   float64
#  61  TCO Solaire (%)                                               87696 non-null   float64
#  62  TCH Solaire (%)                                               87696 non-null   float64
#  63  TCO Hydraulique (%)                                           87696 non-null   float64
#  64  TCH Hydraulique (%)                                           87696 non-null   float64
#  65  TCO Bioénergies (%)                                           87696 non-null   float64
#  66  TCH Bioénergies (%)                                           87696 non-null   float64
#  67  Unnamed: 67                                                   0 non-null       float64
#  68  Unnamed: 65                                                   0 non-null       float64
#  69  Unnamed: 29                                                   0 non-null       float64
# dtypes: float64(20), object(50)
# memory usage: 93.7+ MB

# %%
df_ele = df_ele.drop(columns=['Unnamed: 67','Unnamed: 65','Unnamed: 29'])

# %%
feauture = ['Périmètre','Nature','Date','Heures','Consommation']
df_con = df_ele[feauture].copy()

# %%
df_con.isnull().sum()
# Out:
# Périmètre           0
# Nature              5
# Date                5
# Heures              5
# Consommation    87701
# dtype: int64

# %%
sns.heatmap(df_con.isnull(),cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ### Distribution of consommation before drop NaN

# %%
df_con[['Consommation']].hist()
# Out:
# array([[<Axes: title={'center': 'Consommation'}>]], dtype=object)

# %%
df_con = df_con.dropna()

# %% [markdown]
# ### Distribution of consommation after dropping NaN

# %%
df_con[['Consommation']].hist()
# Out:
# array([[<Axes: title={'center': 'Consommation'}>]], dtype=object)

# %%
sns.heatmap(df_con.isnull(),cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df_con.to_csv("data_ele-2020-2024.csv", index=False)
