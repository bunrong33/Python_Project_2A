# %% [markdown]
# # Temperature and Electricity Consumption in France
#
# ## 1. Introduction
# - Motivation
# - Research question
# - Why France, why temperature
#
# ## 2. Data Sources
# - Electricity data (RTE)
# - Weather data (NASA POWER API)
# - Time period, regions
#
# ## 3. Data Preparation
# - Aggregation
# - Merging
# - Missing values
#
# ## 4. Descriptive Statistics
# - Summary tables
# - Key figures
# - Seasonal patterns
#
# ## 5. Relationship Between Temperature and Consumption
# - Correlations
# - Time series (indexed by region)
#
# ## 6. Regression Analysis
# - Pooled regression
# - Region-specific regressions
# - Interpretation
#
# ## 7. Discussion
# - Île-de-France case
# - Regional heterogeneity
# - What temperature explains vs what it doesn’t
#
# ## 8. Limitations
# - Omitted variables
# - Non-causality
# - Data aggregation
#
# ## 9. Conclusion
# - Answer to the research question
# - What we learned
# - Possible extensions

# %% [markdown]
# ## 1. Introduction
#
# Electricity consumption is a central issue for modern economies, as it reflects household behavior and economic activity while posing major challenges for energy planning and grid stability. In a context of climate change and increasing weather variability, understanding the determinants of electricity demand is particularly important.
#
# Among these determinants, temperature plays a key role, as it is a major constraint in the daily lives of people, be it at their workplace or at home. A broken heater can turn a good winter day into a nightmare. On the general scale, in countries where heating relies mainly on electricity, colder temperatures are typically associated with higher electricity demand, while warmer periods correspond to lower consumption. These effects are often seasonal and may differ across regions depending on climate, population density, and economic structure.
#
# This project investigates the relationship between **daily temperature and electricity consumption across French regions** over the period **2020–2024**. France provides a relevant case study due to its diverse regional climate, its relatively high share of electric heating (66% according to EDF), and the availability of detailed open data on both electricity consumption and weather conditions.
#
# The main research question is:
#
# > **To what extent does daily temperature influence electricity consumption across regions in France?**
#
# To address this question, the analysis proceeds in three steps. First, descriptive statistics are used to document regional and seasonal patterns. Second, the relationship between temperature and electricity consumption is explored using correlations and time-series visualizations. These results motivate a more formal econometric analysis presented later in the report.

# %% [markdown]
# ## 2. Data Sources
#
# This study relies on two main sources of open data, both available at a daily frequency and covering the period from **January 1, 2020 to December 31, 2024**.
#
# ### 2.1 Electricity Consumption Data
#
# Electricity consumption data are obtained from the French electricity transmission system operator (RTE). The dataset provides **daily electricity consumption aggregated at the regional level** for metropolitan France, measured in megawatt-hours (MWh).
#
# These data allow for the analysis of temporal dynamics and regional heterogeneity in electricity demand across France.
#
# ### 2.2 Weather Data
#
# Weather data are retrieved from the **NASA POWER API**, which provides standardized meteorological variables derived from satellite observations and reanalysis products. The main variable used in this study is the **daily mean temperature at 2 meters (T2M)**, expressed in degrees Celsius.
#
# The API allows reproducible access to historical weather data at specific geographic coordinates, making it possible to construct consistent regional temperature indicators.

# %% [markdown]
# ## 3. Data Preparation
#
# Electricity consumption and weather data originate from different sources and therefore require preprocessing before joint analysis.
#
# Electricity consumption data obtained from RTE are aggregated at the **daily regional level**. This aggregation aligns the data with the daily frequency of weather observations and smooths short-term intra-day fluctuations, allowing the analysis to focus on demand variations that are plausibly related to temperature.
#
# Weather data are constructed using **multiple representative geographic points within each region**. For each region, daily mean temperature (T2M) is computed as the average across these points, capturing regional climatic conditions while reducing sensitivity to any single location.
#
# <center> <img src="/home/onyxia/work/Python_Project_2A/figure/weather_map.png" alt="Drawing" style="width: 600px;"/> </center>
#
# **Figure 1** shows that weather observations are spatially distributed within each region rather than concentrated at a single location. This spatial coverage supports the construction of regional temperature series that are representative of overall regional climatic conditions and less sensitive to local extremes.
#
# After harmonizing date formats and regional identifiers, electricity consumption and weather data are merged using **region and date** as common keys. Basic validation checks confirm the consistency of the merged dataset and the absence of systematic missing values.

# %% [markdown]
# ## 4. Descriptive Statistics
#
# This section presents descriptive statistics for electricity consumption and temperature in order to characterize overall patterns, regional heterogeneity, and seasonal variation prior to formal analysis.
#
# ### 4.1 Regional Differences in Electricity Consumption
#
# Average electricity consumption differs substantially across regions, with large differences in baseline demand across France.
#
# <center>
# <img src="../figure/avg_ele_consumption_region.png" alt="Average electricity consumption by region" style="width: 600px;"/>
# </center>
#
# **Figure 2.** Average daily electricity consumption by region.
#
# We observe strong regional heterogeneity in electricity consumption. Île-de-France stands out as a clear outlier with the highest average demand, indicating that baseline consumption levels differ substantially across regions and cannot be explained by temperature alone.
#
#
#
# **New figure**
#
# The violin plots highlight a major contrast in demand volatility between different parts of the country.
# <center>
# <img src="../figure/consummation_distribution.png" alt="Electricity consumption distribution" style="width: 600px;"/>
# </center>
#
# **Figure 3.** Distribution of daily electricity consumption by region
#
#  Regions with the highest consumption, such as Auvergne-Rhône-Alpes, show very wide distributions, reflecting a daily demand that fluctuates significantly. In comparison, the narrow shapes seen in regions like Bretagne or Normandie point to a much more stable and consistent energy load throughout the year.
#
#  **New figure**
#
#
# The boxplots reveal that while median temperatures remain relatively close across the country, the thermal range differs significantly between the coast and the interior.
# <center>
# <img src="../figure/temperature_distribution.png" alt="Temperature distribution" style="width: 600px;"/>
# </center>
#
# **Figure 4.** Temperature distributions by regions
#
# Southern regions like PACA and Occitanie show much higher maximums, while continental areas like Grand-Est experience more extreme cold spikes. In contrast, Bretagne has a much tighter distribution with fewer extremes, which likely explains why its energy demand remains more stable than in regions prone to severe winter temperatures.
#
#
#
# ### 4.2 Seasonal Patterns
#
# Electricity consumption and temperature exhibit clear and opposite seasonal patterns over the year.
#
# <center>
# <img src="../figure/seasonal_pattern.png" alt="National electricity consumption and temperature over time" style="width: 600px;"/>
# </center>
#
# **Figure 3.** National average daily electricity consumption and temperature over time.
#
# We observe a strong inverse seasonal relationship between the two variables: periods of low temperature coincide with peaks in electricity demand. This pattern is consistent with increased heating needs during colder months and suggests that temperature plays an important role in driving seasonal variations in electricity consumption.
#
# ### 4.3 Year-by-Year Regional Comparison
#
# To assess the stability of regional patterns over time, yearly averages of electricity consumption and temperature are computed for each region.
#
# <center>
# <img src="../figure/yearly_temperature_by_region.png" alt="Average yearly temperature by region" style="width: 600px;"/>
# </center>
#
# <center>
# <img src="../figure/yearly_consumption_by_region.png" alt="Average yearly electricity consumption by region" style="width: 600px;"/>
# </center>
#
# **Figure 4.** Average yearly temperature and electricity consumption by region.
#
# We observe that both temperature and electricity consumption patterns are stable across regions over time. While southern regions consistently exhibit higher average temperatures and northern regions remain colder, Île-de-France does not rank among the coldest regions. Despite this, it consistently displays the highest electricity consumption across all years. This contrast indicates that high electricity demand in Île-de-France is largely driven by structural factors rather than climatic conditions, while temperature mainly explains short-run fluctuations within regions.

# %% [markdown]
# ## 5. Relationship Between Temperature and Electricity Consumption
#
# This section explores the relationship between daily temperature and electricity consumption across regions, focusing on correlations and within-region variation.
#
# ### 5.1 Correlation Analysis
#
# <center>
# <img src="../figure/ele_vs_consommation.png" alt="Average electricity consumption by region" style="width: 600px;"/>
# </center>
